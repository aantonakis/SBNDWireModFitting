# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.interpolate import griddata
import uproot
import sys

sys.path.append('/exp/sbnd/data/users/aantonak/SBNDWireModFitting/')

# %%
FILE_DIR = "/exp/sbnd/data/users/aantonak/WireData/CRTvsTPCGen1/"

MC_CRT_F = FILE_DIR+"WIRE_MC_CRT_YZ_GEN1_Full_conv.root"
MC_TPC_F = FILE_DIR+"WIRE_MC_TPC_YZ_GEN1_Full_conv.root"
DATA_CRT_F = FILE_DIR+"WIRE_DATA_CRT_YZ_GEN1_Full_conv.root"
DATA_TPC_F = FILE_DIR+"WIRE_DATA_TPC_YZ_GEN1_Full_conv.root"

# %% [markdown]
# # Plot CRT Stuff

# %%
TPC = 0
fig, axes = plt.subplots(3, 2, figsize=(18, 16))
for plane in range(3):
    idx = 3*TPC + plane

    mc_f = uproot.open(MC_CRT_F)
    data_f = uproot.open(DATA_CRT_F)
    hmc = mc_f["hTrack"+str(idx)]
    hd = data_f["hTrack"+str(idx)]

    print(type(hmc))
    print(hmc.classname)
    z_values, x_edges, y_edges = hmc.to_numpy()
 
    #z_values = z_values.T

    # MC First
    z_masked = np.ma.masked_where(z_values == 0, z_values)
    cmap = plt.cm.viridis.copy()
    cmap.set_bad(color='white')

    #X, Y = np.meshgrid(x_edges, y_edges, indexing='ij') 
    X, Y = np.meshgrid(y_edges, x_edges)
    
    pcm = axes[plane][0].pcolormesh(X, Y, z_masked, cmap=cmap, rasterized=True, shading='auto')

    fig.colorbar(pcm, ax=axes[plane][0]) 
    axes[plane][0].set_title(f"MC CRT Selection (v10_06_00_09): TPC {TPC}, Plane {plane}")     
    #hmc.Delete()

    # Data Second

    #z_values, x_edges, y_edges = hd.to_numpy()
    z_values, x_edges, y_edges = hd.to_numpy()

    #x_edges, y_edges, z_values = root_th2d_to_plt_hist2d(hd)
    z_masked = np.ma.masked_where(z_values == 0, z_values)
    cmap = plt.cm.viridis.copy()
    cmap.set_bad(color='white')

    X, Y = np.meshgrid(y_edges, x_edges)  # Needed for pcolormesh
    #pcm = axs.pcolormesh(X, Y, z_masked, cmap=cmap, shading='auto', vmin=zlim[0], vmax=zlim[1])
    pcm = axes[plane][1].pcolormesh(X, Y, z_masked, cmap=cmap, rasterized=True, shading='auto')

    fig.colorbar(pcm, ax=axes[plane][1]) 
    axes[plane][1].set_title(f"Data CRT Selection (v10_06_00_09): TPC {TPC}, Plane {plane}")     
    #hd.Delete()

fig.supxlabel("Reconstructed Z [cm]", fontsize=30)
fig.supylabel('Reconstructed Y [cm]', fontsize=30)
plt.tight_layout()
#plt.savefig(Figure_Dir + f"tracks_yz_east_tpc{TPC}_plane{plane}.png", bbox_inches="tight")
plt.show()
# Out:
# <class 'uproot.models.TH.Model_TH2D_v4'>
# TH2D
# <class 'uproot.models.TH.Model_TH2D_v4'>
# TH2D
# <class 'uproot.models.TH.Model_TH2D_v4'>
# TH2D

# %%
TPC = 1
fig, axes = plt.subplots(3, 2, figsize=(18, 16))
for plane in range(3):
    idx = 3*TPC + plane

    mc_f = uproot.open(MC_CRT_F)
    data_f = uproot.open(DATA_CRT_F)
    hmc = mc_f["hTrack"+str(idx)]
    hd = data_f["hTrack"+str(idx)]

    z_values, x_edges, y_edges = hmc.to_numpy()
 
    #z_values = z_values.T

    # MC First
    z_masked = np.ma.masked_where(z_values == 0, z_values)
    cmap = plt.cm.viridis.copy()
    cmap.set_bad(color='white')

    #X, Y = np.meshgrid(x_edges, y_edges, indexing='ij') 
    X, Y = np.meshgrid(y_edges, x_edges)
    
    pcm = axes[plane][0].pcolormesh(X, Y, z_masked, cmap=cmap, rasterized=True, shading='auto')

    fig.colorbar(pcm, ax=axes[plane][0]) 
    axes[plane][0].set_title(f"MC CRT Selection (v10_06_00_09): TPC {TPC}, Plane {plane}")     
    #hmc.Delete()

    # Data Second

    #z_values, x_edges, y_edges = hd.to_numpy()
    z_values, x_edges, y_edges = hd.to_numpy()

    #x_edges, y_edges, z_values = root_th2d_to_plt_hist2d(hd)
    z_masked = np.ma.masked_where(z_values == 0, z_values)
    cmap = plt.cm.viridis.copy()
    cmap.set_bad(color='white')

    X, Y = np.meshgrid(y_edges, x_edges)  # Needed for pcolormesh
    #pcm = axs.pcolormesh(X, Y, z_masked, cmap=cmap, shading='auto', vmin=zlim[0], vmax=zlim[1])
    pcm = axes[plane][1].pcolormesh(X, Y, z_masked, cmap=cmap, rasterized=True, shading='auto')

    fig.colorbar(pcm, ax=axes[plane][1]) 
    axes[plane][1].set_title(f"Data CRT Selection (v10_06_00_09): TPC {TPC}, Plane {plane}")     
    #hd.Delete()

fig.supxlabel("Reconstructed Z [cm]", fontsize=30)
fig.supylabel('Reconstructed Y [cm]', fontsize=30)
plt.tight_layout()
#plt.savefig(Figure_Dir + f"tracks_yz_east_tpc{TPC}_plane{plane}.png", bbox_inches="tight")
plt.show()

# %%
TPC = 0
fig, axes = plt.subplots(3, 2, figsize=(18, 16))
for plane in range(3):
    idx = 3*TPC + plane

    mc_f = uproot.open(MC_TPC_F)
    data_f = uproot.open(DATA_TPC_F)
    hmc = mc_f["hTrack"+str(idx)]
    hd = data_f["hTrack"+str(idx)]

    z_values, x_edges, y_edges = hmc.to_numpy()
 
    #z_values = z_values.T

    # MC First
    z_masked = np.ma.masked_where(z_values == 0, z_values)
    cmap = plt.cm.viridis.copy()
    cmap.set_bad(color='white')

    #X, Y = np.meshgrid(x_edges, y_edges, indexing='ij') 
    X, Y = np.meshgrid(y_edges, x_edges)
    
    pcm = axes[plane][0].pcolormesh(X, Y, z_masked, cmap=cmap, rasterized=True, shading='auto')

    fig.colorbar(pcm, ax=axes[plane][0]) 
    axes[plane][0].set_title(f"MC TPC Selection (v10_06_00_09): TPC {TPC}, Plane {plane}")     
    #hmc.Delete()

    # Data Second

    #z_values, x_edges, y_edges = hd.to_numpy()
    z_values, x_edges, y_edges = hd.to_numpy()

    #x_edges, y_edges, z_values = root_th2d_to_plt_hist2d(hd)
    z_masked = np.ma.masked_where(z_values == 0, z_values)
    cmap = plt.cm.viridis.copy()
    cmap.set_bad(color='white')

    X, Y = np.meshgrid(y_edges, x_edges)  # Needed for pcolormesh
    #pcm = axs.pcolormesh(X, Y, z_masked, cmap=cmap, shading='auto', vmin=zlim[0], vmax=zlim[1])
    pcm = axes[plane][1].pcolormesh(X, Y, z_masked, cmap=cmap, rasterized=True, shading='auto')

    fig.colorbar(pcm, ax=axes[plane][1]) 
    axes[plane][1].set_title(f"Data TPC Selection (v10_06_00_09): TPC {TPC}, Plane {plane}")     
    #hd.Delete()

fig.supxlabel("Reconstructed Z [cm]", fontsize=30)
fig.supylabel('Reconstructed Y [cm]', fontsize=30)
plt.tight_layout()
#plt.savefig(Figure_Dir + f"tracks_yz_east_tpc{TPC}_plane{plane}.png", bbox_inches="tight")
plt.show()

# %%
TPC = 1
fig, axes = plt.subplots(3, 2, figsize=(18, 16))
for plane in range(3):
    idx = 3*TPC + plane

    mc_f = uproot.open(MC_TPC_F)
    data_f = uproot.open(DATA_TPC_F)
    hmc = mc_f["hTrack"+str(idx)]
    hd = data_f["hTrack"+str(idx)]

    z_values, x_edges, y_edges = hmc.to_numpy()
 
    #z_values = z_values.T

    # MC First
    z_masked = np.ma.masked_where(z_values == 0, z_values)
    cmap = plt.cm.viridis.copy()
    cmap.set_bad(color='white')

    #X, Y = np.meshgrid(x_edges, y_edges, indexing='ij') 
    X, Y = np.meshgrid(y_edges, x_edges)
    
    pcm = axes[plane][0].pcolormesh(X, Y, z_masked, cmap=cmap, rasterized=True, shading='auto')

    fig.colorbar(pcm, ax=axes[plane][0]) 
    axes[plane][0].set_title(f"MC TPC Selection (v10_06_00_09): TPC {TPC}, Plane {plane}")     
    #hmc.Delete()

    # Data Second

    #z_values, x_edges, y_edges = hd.to_numpy()
    z_values, x_edges, y_edges = hd.to_numpy()

    #x_edges, y_edges, z_values = root_th2d_to_plt_hist2d(hd)
    z_masked = np.ma.masked_where(z_values == 0, z_values)
    cmap = plt.cm.viridis.copy()
    cmap.set_bad(color='white')

    X, Y = np.meshgrid(y_edges, x_edges)  # Needed for pcolormesh
    #pcm = axs.pcolormesh(X, Y, z_masked, cmap=cmap, shading='auto', vmin=zlim[0], vmax=zlim[1])
    pcm = axes[plane][1].pcolormesh(X, Y, z_masked, cmap=cmap, rasterized=True, shading='auto')

    fig.colorbar(pcm, ax=axes[plane][1]) 
    axes[plane][1].set_title(f"Data TPC Selection (v10_06_00_09): TPC {TPC}, Plane {plane}")     
    #hd.Delete()

fig.supxlabel("Reconstructed Z [cm]", fontsize=30)
fig.supylabel('Reconstructed Y [cm]', fontsize=30)
plt.tight_layout()
#plt.savefig(Figure_Dir + f"tracks_yz_east_tpc{TPC}_plane{plane}.png", bbox_inches="tight")
plt.show()
